# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error , mean_squared_error
'''Goal : To Predict car price with the porperties of the car'''

# %%
df = pd.read_csv(r"C:\Users\Ittikorn\OneDrive\Desktop\Ai\Machinelearning\ssswork\CarPrices.csv")

# %%
df.head()

# %%
df.describe()

# %%
df.drop(["car_ID","CarName"],axis=1,inplace=True)
df = pd.get_dummies(df, drop_first=True) #ทำ One-Hot Encoding กับ column ที่เป็นข้อความ

# %%
df.head(24)

# %%
df.isnull()

# %%
df.replace('4wd','fwd',inplace=True)

# %%
df.head()

# %%
X = df.drop("price", axis=1)
y = df["price"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
#Model Evaluatioท
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAE:", mae)
print("RMSE:", rmse)

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted")
plt.show()
